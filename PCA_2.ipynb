# %% [markdown]
# # importing required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.decomposition import PCA

# %%
df= pd.read_csv("/content/Pulsar.csv")
df.head(5)
# Out:
#    Mean_Integrated         SD        EK  Skewness  Mean_DMSNR_Curve  \
# 0       140.562500  55.683782 -0.234571 -0.699648          3.199833
# 1       102.507812  58.882430  0.465318 -0.515088          1.677258
# 2       103.015625  39.341649  0.323328  1.051164          3.121237
# 3       136.750000  57.178449 -0.068415 -0.636238          3.642977
# 4        88.726562  40.672225  0.600866  1.123492          1.178930
#
#    SD_DMSNR_Curve  EK_DMSNR_Curve  Skewness_DMSNR_Curve  Class
# 0       19.110426        7.975532             74.242225      0
# 1       14.860146       10.576487            127.393580      0
# 2       21.744669        7.735822             63.171909      0
# 3       20.959280        6.896499             53.593661      0
# 4       11.468720       14.269573            252.567306      0

# %% [markdown]
# # importing required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.decomposition import PCA

# %%
df= pd.read_csv("/content/Pulsar.csv")
df.head(5)
# Out:
#    Mean_Integrated         SD        EK  Skewness  Mean_DMSNR_Curve  \
# 0       140.562500  55.683782 -0.234571 -0.699648          3.199833
# 1       102.507812  58.882430  0.465318 -0.515088          1.677258
# 2       103.015625  39.341649  0.323328  1.051164          3.121237
# 3       136.750000  57.178449 -0.068415 -0.636238          3.642977
# 4        88.726562  40.672225  0.600866  1.123492          1.178930
#
#    SD_DMSNR_Curve  EK_DMSNR_Curve  Skewness_DMSNR_Curve  Class
# 0       19.110426        7.975532             74.242225      0
# 1       14.860146       10.576487            127.393580      0
# 2       21.744669        7.735822             63.171909      0
# 3       20.959280        6.896499             53.593661      0
# 4       11.468720       14.269573            252.567306      0

# %%
df.columns
# Out:
# Index(['Mean_Integrated', 'SD', 'EK', 'Skewness', 'Mean_DMSNR_Curve',
#        'SD_DMSNR_Curve', 'EK_DMSNR_Curve', 'Skewness_DMSNR_Curve', 'Class'],
#       dtype='object')

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X.corr()
# Out:
#                       Mean_Integrated        SD        EK  Skewness  \
# Mean_Integrated              1.000000  0.547137 -0.873898 -0.738775
# SD                           0.547137  1.000000 -0.521435 -0.539793
# EK                          -0.873898 -0.521435  1.000000  0.945729
# Skewness                    -0.738775 -0.539793  0.945729  1.000000
# Mean_DMSNR_Curve            -0.298841  0.006869  0.414368  0.412056
# SD_DMSNR_Curve              -0.307016 -0.047632  0.432880  0.415140
# EK_DMSNR_Curve               0.234331  0.029429 -0.341209 -0.328843
# Skewness_DMSNR_Curve         0.144033  0.027691 -0.214491 -0.204782
#
#                       Mean_DMSNR_Curve  SD_DMSNR_Curve  EK_DMSNR_Curve  \
# Mean_Integrated              -0.298841       -0.307016        0.234331
# SD                            0.006869       -0.047632        0.029429
# EK                            0.414368        0.432880       -0.341209
# Skewness                      0.412056        0.415140       -0.328843
# Mean_DMSNR_Curve              1.000000        0.796555       -0.615971
# SD_DMSNR_Curve                0.796555        1.000000       -0.809786
# EK_DMSNR_Curve               -0.615971       -0.809786        1.000000
# Skewness_DMSNR_Curve         -0.354269       -0.575800        0.923743
#
#                       Skewness_DMSNR_Curve
# Mean_Integrated                   0.144033
# SD                                0.027691
# EK                               -0.214491
# Skewness                         -0.204782
# Mean_DMSNR_Curve                 -0.354269
# SD_DMSNR_Curve                   -0.575800
# EK_DMSNR_Curve                    0.923743
# Skewness_DMSNR_Curve              1.000000

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
n_components = 3
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)
explained_variance = pca.explained_variance_ratio_
print (explained_variance)
# Out:
# [0.51675584 0.26807564 0.10116862]

# %%
X_pca
# Out:
# array([[-1.27884879, -1.27313333,  0.0162129 ],
#        [-1.02055347, -0.20116189,  0.6704783 ],
#        [ 0.18828859,  0.43211417, -0.97976616],
#        ...,
#        [ 0.68183395, -2.6861702 ,  0.44991441],
#        [-1.10391246, -0.11650828,  0.32088421],
#        [ 3.71252289, -4.90385741,  5.28427467]])

# %%
# Create a DataFrame with the principal components
columns_pca = [f'PC{i + 1}' for i in range(n_components)]
df_pca = pd.DataFrame(data=X_pca, columns=columns_pca)
df_result = pd.concat([df_pca, df['Class']], axis=1)
print(df_result.head())
# Out:
#         PC1       PC2       PC3  Class
# 0 -1.278849 -1.273133  0.016213      0
# 1 -1.020553 -0.201162  0.670478      0
# 2  0.188289  0.432114 -0.979766      0
# 3 -1.015466 -1.469881 -0.018832      0
# 4 -0.822626  2.123651  0.407953      0
